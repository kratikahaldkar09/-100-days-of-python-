# %% [markdown]
# ##Convert kilometer to miles.

# %%
km=float(input("enter the value:"))
mile=0.621371*km
print("enter the converted value to miles",mile)
# Out:
# enter the value:23
# enter the converted value to miles 14.291533

# %% [markdown]
# ##number is odd or even

# %%
a=int(input("enter a number  "))
if(a%2==0):
 print("number is even")
else:
  print("number is odd")
# Out:
# enter a number  23
# number is odd

# %% [markdown]
# ##postive number or negative

# %%
a=int(input("enter a number  "))
if(a>0):
  print("number is postive")
else:
  print("number is negative")
# Out:
# enter a number  1
# number is postive
