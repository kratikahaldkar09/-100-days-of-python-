# %% [markdown]
# #Modules
# ###modules is like a code library which can be used to borrow the  code  written by somebody else in our program.
#
# ##two types of modules :-
# 1. Built in modules
# 2.External modules

# %% [markdown]
# #Pip command
#
# ##it can be used as a package  manager pip install a pyhthon module
#
# ##let install a module called pandas using the following command

# %%
pip install pandas

# %%
print("hello",5,6)
# Out:
# hello 5 6

# %%
print(12*4)
print(45+34)
# Out:
# 48
# 79

# %% [markdown]
# #COMMENTS(#)

# %%
# remove this line
print("comments")
# Out:
# comments

# %% [markdown]
# #multi line comments
#
# ##triple single code
# ##''' hello '''
#
# ##triple double code
# ##"""hello"""

# %%
'''
this is a multiline code
this is second lines of code
this is third lines of code
'''
print("multiline comments")
# Out:
# multiline comments

# %% [markdown]
# #ESCAPE SEQUENCE
# ##[
# ##\n
# means
# (new line)
# ##]

# %%
print("i am a good girl \n and my best friend are also a good girl")
# Out:
# i am a good girl
#  and my best friend are also a good girl

# %% [markdown]
# ##more on print statement

# %%
print("hello",4,5,6,sep="~")
print("hello",4,5,6,sep="-")
print("hello",4,5,6,end="009\n")
# Out:
# hello~4~5~6
# hello-4-5-6
# hello 4 5 6009
