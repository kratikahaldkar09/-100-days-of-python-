# %%
# !pip install numpy

# %% [markdown]
# #variables
#
# ##variable is like a container that hold data .Very similar to how our container in kitchen hold suger ,salt etc.
#
# ##creting a variable is just like creation placeholder in memory and assiging it some value.

# %%
a=1
b=True
c="code"
print(a)
print(b)
print(c)
# Out:
# 1
# True
# code

# %% [markdown]
# #data types
#
# ##data type specifies the type of value a variable hold. This is requried in the programming to do various operations without causing any error.

# %%
a=1
print(type(a))
b="krati"
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ##1.arithmetic operator :- +,-,*,/

# %%
# calculator
a=10
b=2
print('sum is:',a+b)
print('difference is:',a-b)
print('mulitiplication is:',a*b)
print('division is:',a/b)
print('reminder is :',a//b)
print(a%b)
# Out:
# sum is: 12
# difference is: 8
# mulitiplication is: 20
# division is: 5.0
# reminder is : 5
# 0
