# %% [markdown]
# #TYPE CASTING IN PYTHON
#
# ##The conversion of one data type to another data type is called type casting
#
# ##Two type of type casting:-
#
# ##1.Explicit type casting
# ##2.Implicit type casting

# %%
# explicit type casting
a="13"
b=4
c=int(a)
sum=c+b
print("sum is:",sum)
# Out:
# sum is: 17

# %%
# Implicit type casting
a=1.2
b=6
print(a+b)
# Out:
# 7.2

# %% [markdown]
# ##TAKING  USER INPUT IN PYTHON

# %%
a=input("enter first number:")
b=input("enter second number:")
print(int(a)+int(b))
# Out:
# enter first number:3
# enter second number:5
# 8

# %%
a=input("enter first number:")
b=input("enter second number:")
print(int(a)+int(b))
print(int(a)-int(b))
print(int(a)*int(b))
print(int(a)/int(b))
print(int(a)//int(b))
print(int(a)%int(b))
# Out:
# enter first number:3
# enter second number:2
# 5
# 1
# 6
# 1.5
# 1
# 1

# %% [markdown]
# ##finding square root.

# %%
a=25
sqr=a**(1/2)
print(" the square root of the given number:",sqr)
# Out:
#  the square root of the given number: 5.0

# %% [markdown]
# ##area of triangle

# %%
a=int(input("enter a first number:"))
b=int(input("enter a second number:"))
area=1/2*a*b
print("area of triangle is :",area)
# Out:
# enter a first number:3
# enter a second number:5
# area of triangle is : 7.5

# %% [markdown]
# ##swapping two variable

# %%
x=12
y=89
temp=x
x=y
print("value of x is:",x)
y=temp
print("the value of y is:",y)
# Out:
# value of x is: 89
# the value of y is: 12
