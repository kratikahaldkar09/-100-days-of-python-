# %% [markdown]
# >
# #what is python ?
#
# ##python is a interpreted, object oriented,high level programming language , dynamic semaintic.

# %% [markdown]
# #Features of pyhon?
#
# ##1.easy to learn
# ##2.open source
# ##3.high level language
# ##4.cross platform
# ##5.standard library

# %% [markdown]
# #Application of python
#
# ##1.website and application development
# ##2.network programming
# ##3.data analysis
# ##4.game development
# ##5.ML and AI
# ##6.scientific calculation
# ##7.web scaping
# ##8.data visulization

# %%
print("Hello world")
# Out:
# Hello world

# %%
print(45)
# Out:
# 45
